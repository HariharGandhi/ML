# %%
#step-5 :Running Actual Program(SLR)
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Load dataset
my_dict = {
    'height': [151, 174, 138, 186, 128, 136, 179, 163, 152, 131],
    'weight': [63, 81, 56, 91, 47, 57, 76, 72, 62, 48]
    
}
dataset = pd.DataFrame(my_dict)

# %%
# To display dataset
print(dataset)
x=dataset.iloc[:,:-1].values
X=dataset.iloc[:,:-1].values
y=dataset.iloc[:,1].values
print(X)
print(y)
# Out:
#    height  weight
# 0     151      63
# 1     174      81
# 2     138      56
# 3     186      91
# 4     128      47
# 5     136      57
# 6     179      76
# 7     163      72
# 8     152      62
# 9     131      48
# [[151]
#  [174]
#  [138]
#  [186]
#  [128]
#  [136]
#  [179]
#  [163]
#  [152]
#  [131]]
# [63 81 56 91 47 57 76 72 62 48]

# %%
#from sklearn subpackage import linear regression model
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(X,y)
# Out:
# LinearRegression()

# %%
#To get the slop
regressor.coef_
# Out:
# array([0.67461045])

# %%
#To get the y intercept
regressor.intercept_
# Out:
# -38.45508707607701

# %%
#To print the equation of line
print("y= "+ str(regressor.coef_) + "X + " + str(regressor.intercept_))
# Out:
# y= [0.67461045]X + -38.45508707607701

# %%
#To get the slop
print("Accuracy:",regressor.score(X,y)*100)
# Out:
# Accuracy: 95.47822477500306

# %%
#To plot graph
plt.plot(X,y,'o')
plt.plot(X,regressor.predict(X));
plt.show()
predict_x=float(input('Enter Height:'))
predict_y=(0.67461045*predict_x)-38.45508707607698
plt.scatter(X,y)
plt.scatter(predict_x,predict_y) 
plt.xlabel('Height:(Predicted_x)') 
plt.ylabel('Weight:(Predicted_y)')
# Out:
# Enter Height:0.64
# Text(0, 0.5, 'Weight:(Predicted_y)')

# %%
#plotting the Predicted regression line 
plt.plot(X,regressor.predict(X),color='green');
plt.show()
